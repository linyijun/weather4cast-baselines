# %%
import torch 
import torch.nn as nn


encoder_layer = nn.TransformerEncoderLayer(d_model=512, nhead=8)
encoder = torch.nn.TransformerEncoder(encoder_layer, num_layers=8)
src = torch.rand(10, 32, 512)
out = encoder(src)
print(out.shape)
# Out:
# torch.Size([10, 32, 512])

# %%
from plotting import plot_N



images = [v.mask, v.data, v.filled(np.nan)]
texts = ['mask', 'data using default _FillValue', 'data using NaN for missing values']
plot_N(images, texts)

# %%
import matplotlib.pyplot as plt

cmap = plt.cm.get_cmap("hsv", 10)
labels = ['CTTH_temperature', 'CRR_crr_intensity', 'ASII_asii_turb_trop_prob', 'CMA_cma']

plt.figure(figsize=(15, 6))
for i in range(t.shape[1]):
    plt.plot(range(96), np.mean(t[:, i, 0:128, 0:128], axis=(1, 2)), marker='.', color=cmap(i), label=labels[i])

plt.ylim(-0.1, 1)
plt.legend(prop={'size': 15})
plt.show()
plt.close()

plt.figure(figsize=(15, 6))
for i in range(t.shape[1]):
    plt.plot(range(96), np.mean(t[:, i, 128:, 0:128], axis=(1, 2)), marker='.', color=cmap(i), label=labels[i])

plt.ylim(-0.1, 1)
plt.legend(prop={'size': 15})
plt.show()
plt.close()

plt.figure(figsize=(15, 6))
for i in range(t.shape[1]):
    plt.plot(range(96), np.mean(t[:, i, 0:128, 128:], axis=(1, 2)), marker='.', color=cmap(i), label=labels[i])

plt.ylim(-0.1, 1)
plt.legend(prop={'size': 15})
plt.show()
plt.close()

plt.figure(figsize=(15, 6))
for i in range(t.shape[1]):
    plt.plot(range(96), np.mean(t[:, i, 128:, 128:], axis=(1, 2)), marker='.', color=cmap(i), label=labels[i])

plt.ylim(-0.1, 1)
plt.legend(prop={'size': 15})
plt.show()
plt.close()

# %%
# Out:
# cpu
# ...

# %%
data_path = '/home/yaoyi/lin00786/weather4cast/preprocess-data/'
sample_path = '/home/yaoyi/lin00786/weather4cast/weather4cast-test/samples.csv'

a = WMDataset(data_path, sample_path)
a = a.get_item(idx=0)
# Out:
# (4, 4, 256, 256) (32, 1, 256, 256)

# %%
from data_utils.utils import get_idxs_w_blacklist

get_idxs_w_blacklist([264], blacklist_path='/home/yaoyi/lin00786/weather4cast/blacklist.json')
# Out:
# [(264, 0),
#  (264, 1),
#  (264, 2),
#  (264, 3),
#  (264, 4),
#  (264, 5),
#  (264, 6),
#  (264, 7),
#  (264, 8),
#  (264, 9),
#  (264, 10),
#  (264, 11),
#  (264, 12),
#  (264, 13),
#  (264, 14),
#  (264, 15),
#  (264, 16),
#  (264, 17),
#  (264, 18),
#  (264, 19),
#  (264, 20),
#  (264, 21),
#  (264, 22),
#  (264, 23),
#  (264, 24),
#  (264, 25),
#  (264, 26),
#  (264, 27),
#  (264, 28),
#  (264, 29),
#  (264, 30),
#  (264, 31),
#  (264, 32),
#  (264, 33),
#  (264, 34),
#  (264, 35),
#  (264, 36),
#  (264, 37),
#  (264, 38),
#  (264, 39),
#  (264, 40),
#  (264, 41),
#  (264, 42),
#  (264, 43),
#  (264, 44),
#  (264, 45),
#  (264, 46),
#  (264, 47),
#  (264, 48),
#  (264, 49),
#  (264, 50),
#  (264, 51),
#  (264, 52),
#  (264, 53),
#  (264, 54),
#  (264, 55),
#  (264, 56),
#  (264, 57),
#  (264, 58),
#  (264, 59),
#  (264, 60)]

# %%
# !pwd
# Out:
# /panfs/roc/groups/14/yaoyi/lin00786/weather4cast/weather4cast-test
